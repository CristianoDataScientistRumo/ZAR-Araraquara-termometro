# %% [markdown]
# ## Importando Bibliotecas
# ___
# * Pandas
# * Numpy
# * Seaborn
# * Matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
#!pip install plotly-express

# %% [markdown]
# ## Carregando base de dados

# %%
data_zfn = pd.read_csv("data/ZFN.csv", low_memory=False)
data_zfn
# Out:
#                                        uid regiao              operacao  \
# 0       thermo_id_20001968_20200205_200107  NORTE               ZGI-ZFN
# 1       thermo_id_20001968_20200205_210108  NORTE               ZGI-ZFN
# 2       thermo_id_20001968_20200205_220115  NORTE               ZGI-ZFN
# 3       thermo_id_20001968_20200205_230109  NORTE               ZGI-ZFN
# 4       thermo_id_20001968_20200206_000113  NORTE               ZGI-ZFN
# ...                                    ...    ...                   ...
# 165665  thermo_id_20001968_20241223_224754  NORTE  ZARTMI-ZGIZFN-336500
# 165666  thermo_id_20001968_20241223_230437  NORTE  ZARTMI-ZGIZFN-336500
# 165667  thermo_id_20001968_20241223_231741  NORTE  ZARTMI-ZGIZFN-336500
# 165668  thermo_id_20001968_20241223_233107  NORTE  ZARTMI-ZGIZFN-336500
# 165669  thermo_id_20001968_20241223_231741  NORTE  ZARTMI-ZGIZFN-336500
#
#                   original descritivo  temperatura  temperaturatermometro  \
# 0       thermo_id_20001968        NaN         25.7                   25.7
# 1       thermo_id_20001968        NaN         24.7                   24.7
# 2       thermo_id_20001968        NaN         24.0                   24.0
# 3       thermo_id_20001968        NaN         24.0                   24.0
# 4       thermo_id_20001968        NaN         23.9                   23.9
# ...                    ...        ...          ...                    ...
# 165665  thermo_id_20001968        NaN         26.7                   22.9
# 165666  thermo_id_20001968        NaN         26.8                   22.9
# 165667  thermo_id_20001968        NaN         26.8                   22.9
# 165668  thermo_id_20001968        NaN         26.8                   22.9
# 165669  thermo_id_20001968        NaN         26.8                   22.9
#
#               responsavel      substituidopor  amplitude    status  \
# 0                     NaN                 NaN        3.7    Normal
# 1                     NaN                 NaN        2.7    Normal
# 2                     NaN                 NaN        2.0    Normal
# 3                     NaN                 NaN        2.0    Normal
# 4                     NaN                 NaN        0.0    Normal
# ...                   ...                 ...        ...       ...
# 165665  Supervisorio - TO  thermo_id_20001990        3.4  ErroTOCF
# 165666  Supervisorio - TO  thermo_id_20001990        3.5  ErroTOCF
# 165667  Supervisorio - TO  thermo_id_20001990        3.5  ErroTOCF
# 165668  Supervisorio - TO  thermo_id_20001990        3.5  ErroTOCF
# 165669  Supervisorio - TO  thermo_id_20001990        3.5  ErroTOCF
#
#                   checkedat     dataref  year  month  day
# 0       2020-02-05 20:01:07  2020-02-05  2020      2    5
# 1       2020-02-05 21:01:08  2020-02-05  2020      2    5
# 2       2020-02-05 22:01:15  2020-02-05  2020      2    5
# 3       2020-02-05 23:01:09  2020-02-05  2020      2    5
# 4       2020-02-06 00:01:13  2020-02-06  2020      2    6
# ...                     ...         ...   ...    ...  ...
# 165665  2024-12-23 23:04:37  2024-12-23  2024     12   23
# 165666  2024-12-23 23:17:41  2024-12-23  2024     12   23
# 165667  2024-12-23 23:17:41  2024-12-23  2024     12   23
# 165668  2024-12-23 23:31:07  2024-12-23  2024     12   23
# 165669  2024-12-23 23:31:07  2024-12-23  2024     12   23
#
# [165670 rows x 16 columns]

# %%
data_zfn.dtypes
# Out:
# uid                       object
# regiao                    object
# operacao                  object
# original                  object
# descritivo                object
# temperatura              float64
# temperaturatermometro    float64
# responsavel               object
# substituidopor            object
# amplitude                float64
# status                    object
# checkedat                 object
# dataref                   object
# year                       int64
# month                      int64
# day                        int64
# dtype: object

# %%
# verificando valores faltantes
data_zfn.isnull().sum()
# Out:
# uid                           0
# regiao                        0
# operacao                      0
# original                      0
# descritivo               159745
# temperatura                   0
# temperaturatermometro         0
# responsavel              126012
# substituidopor           126012
# amplitude                     0
# status                        0
# checkedat                     0
# dataref                       0
# year                          0
# month                         0
# day                           0
# dtype: int64

# %%
data_zfn.drop(columns= ["uid", "descritivo", "responsavel", "substituidopor"], inplace=True)

# %%
data_zfn.head()
# Out:
#   regiao operacao            original  temperatura  temperaturatermometro  \
# 0  NORTE  ZGI-ZFN  thermo_id_20001968         25.7                   25.7
# 1  NORTE  ZGI-ZFN  thermo_id_20001968         24.7                   24.7
# 2  NORTE  ZGI-ZFN  thermo_id_20001968         24.0                   24.0
# 3  NORTE  ZGI-ZFN  thermo_id_20001968         24.0                   24.0
# 4  NORTE  ZGI-ZFN  thermo_id_20001968         23.9                   23.9
#
#    amplitude  status            checkedat     dataref  year  month  day
# 0        3.7  Normal  2020-02-05 20:01:07  2020-02-05  2020      2    5
# 1        2.7  Normal  2020-02-05 21:01:08  2020-02-05  2020      2    5
# 2        2.0  Normal  2020-02-05 22:01:15  2020-02-05  2020      2    5
# 3        2.0  Normal  2020-02-05 23:01:09  2020-02-05  2020      2    5
# 4        0.0  Normal  2020-02-06 00:01:13  2020-02-06  2020      2    6

# %%
# Converter 'dataref' para datetime
data_zfn['dataref'] = pd.to_datetime(data_zfn['dataref'])

# %%
# Calcular as temperaturas máxima, mínima e média por dia
agg_data = data_zfn.groupby('dataref')['temperatura'].agg(['max', 'min', 'mean']).reset_index()

# %%
# Renomear colunas para clareza
agg_data.columns = ['dataref', 'Max Temp', 'Min Temp', 'Mean Temp']

# %%
agg_data
# Out:
#         dataref  Max Temp  Min Temp  Mean Temp
# 0    2020-02-05      25.7      24.0  24.600000
# 1    2020-02-06      45.5      22.9  36.948837
# 2    2020-02-07      44.9      22.3  36.402326
# 3    2020-02-08      40.4      22.2  34.036364
# 4    2020-02-09      44.4      22.1  29.732558
# ...         ...       ...       ...        ...
# 1709 2024-12-19      43.4      12.7  30.531765
# 1710 2024-12-20      46.7      22.0  30.566379
# 1711 2024-12-21      47.8      11.4  27.911194
# 1712 2024-12-22      48.5      22.8  33.368456
# 1713 2024-12-23      52.9      23.8  36.407547
#
# [1714 rows x 4 columns]

# %%
# Gerar gráfico com Plotly Express
fig = px.scatter(
    agg_data,
    x='dataref',
    y=['Max Temp', 'Min Temp', 'Mean Temp'],
    title='Temperaturas Máxima, Mínima e Média por Dia',
    labels={'value': 'Temperatura (°C)', 'dataref': 'Data'},
    template='plotly',
)

# Mostrar gráfico
fig.show()
# Out:
# <div>                            <div id="34ba2878-ff01-4028-9b7c-72ff1a4bc38a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34ba2878-ff01-4028-9b7c-72ff1a4bc38a")) {                    Plotly.newPlot(                        "34ba2878-ff01-4028-9b7c-72ff1a4bc38a",                        [{"hovertemplate":"variable=Max Temp\u003cbr\u003eData=%{x}\u003cbr\u003eTemperatura (\u00b0C)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Max Temp","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Max Temp","showlegend":true,"x":["2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-08T00:00:00","2020-02-09T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-15T00:00:00","2020-02-16T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-22T00:00:00","2020-02-23T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-02-29T00:00:00","2020-03-01T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-07T00:00:00","2020-03-08T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-21T00:00:00","2020-03-22T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-28T00:00:00","2020-03-29T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-04T00:00:00","2020-04-05T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-11T00:00:00","2020-04-12T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-18T00:00:00","2020-04-19T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-25T00:00:00","2020-04-26T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-02T00:00:00","2020-05-03T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-09T00:00:00","2020-05-10T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-16T00:00:00","2020-05-17T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-23T00:00:00","2020-05-24T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-05-30T00:00:00","2020-05-31T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-06T00:00:00","2020-06-07T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-13T00:00:00","2020-06-14T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-20T00:00:00","2020-06-21T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-27T00:00:00","2020-06-28T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07- ...
